# %% [markdown]
# # Creating Knowledge Graphs using Pretrained Models

# %% [markdown]
# This notebook takes the 2 models developed in steps 3 and 4 and uses them to run across the full body of texts. First, the named entity extraction model is used to extract the entities, while the relation extractor then classifyies the most likely relationship between these two entities. These are used to pull the information that is then fed into Neo4j to create the knowledge graphs. As neo4j cannot connect well with servers, the knowledge graph code can be found in the notebook 'Creating_Knowledge_Graphs.ipynb'. The data extracted through this notebook is therefore stored as pickle objects and imported to the colab notebook. All copies of the data can be inspected from the 4_Knowledge_Graphs/output <br>
#
# The notebook is split into the following sections:
# 1. Named Entity Recognition
# 2. Relation Extraction

# %% [markdown]
# ## Setup

# %%
# -- General dependencies -- 
import pandas as pd
import json
import csv
from tqdm import tqdm
import pickle

# -- Spacy functions -- 
import spacy
import hashlib

# %% [markdown]
# __Load in the Data__

# %%
# -- Import coreferenced texts -- 
psychedelic_articles = pd.read_csv('../KGs/1_coreference_resolution/data/coreferenced_full_texts.csv')

# %%
# -- inspect -- 
psychedelic_articles[:5]
# Out:
#                                   DOI  \
# 0            10.1177/0269881116675513
# 1  10.1001/archgenpsychiatry.2010.116
# 2               10.1124/pr.115.011478
# 3       10.1016/S2215-0366(16)30065-7
# 4             10.1073/pnas.1119598109
#
#                                           Discussion  \
# 0  The present study demonstrated the efficacy of...
# 1  The initial goals of this research project wer...
# 2  Dr. Albert Hofmann, the natural products chemi...
# 3  In this open-label, single-arm pilot study, we...
# 4  The fMRI studies reported here revealed signif...
#
#                                          Conclusions  \
# 0  When administered under psychologically suppor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                              Coreferenced_Discussion  \
# 0  The present study demonstrated the efficacy of...
# 1  The initial goals of this research project wer...
# 2  Dr. Albert Hofmann, the natural products chemi...
# 3  In this open-label, single-arm pilot study, we...
# 4  The fMRI studies reported here revealed signif...
#
#                             Coreferenced_Conclusions
# 0  When administered under psychologically suppor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# __Preprocess the Data__

# %%
# --- Extract the Discussion column ---  
discussions = []

for index, row in psychedelic_articles.iterrows():
    discussions.append(str(row[3]))
    
print(f"The discussions have been extracted and are now a type: {type(discussions)}.")
# Out:
# The discussions have been extracted and are now a type: <class 'list'>.

# %%
discussions = discussions[:]

# %%
# -- inspect the first discussion -- 
discussions[:1]
# Out:
# ['The present study demonstrated the efficacy of a high dose of psilocybin administered under supportive conditions to decrease symptoms of depressed mood and anxiety, and to increase quality of life in patients with a life-threatening cancer diagnosis. Eleven of 17 therapeutically relevant measures fulfilled conservative criteria for demonstrating efficacy of the high dose of psilocybin (Table 4, Figure 3). The data show that psilocybin produced large and significant decreases in clinician-rated and self-rated measures of depression, anxiety or mood disturbance, and increases in measures of quality of life, life meaning, death acceptance, and optimism. These effects were sustained at 6 months. For the clinician-rated measures of depression and anxiety, respectively, the overall rate of clinical response at 6 months was 78% and 83% and the overall rate of symptom remission was 65% and 57%. Participants attributed to the high-dose experience positive changes in attitudes about life, self, mood, relationships and spirituality, with over 80% endorsing moderately or higher increased well-being or life satisfaction. These positive effects were reflected in significant corresponding changes in ratings by community observers (friends, family, work colleagues) of participant attitudes and behavior.The results substantially extend the findings of a recent double-blind pilot study with a lower dose of psilocybin (14 mg/70 kg) in cancer patients that showed non-significant trends for benefits of psilocybin compared with placebo (niacin) on measures of depression and anxiety, with some significant decreases relative to baseline demonstrated at 1 to 6 months (Grob et al., 2011). The time-course, magnitude, and qualitative features of the high dose of psilocybin on session days were consistent with those observed in previous studies in healthy volunteers (Griffiths et al., 2006, 2011; Johnson et al., 2012).The significant association of mystical-type experience (MEQ30) during Session 1 with most of the enduring changes in therapeutic outcome measures 5 weeks later (Figure 5) is consistent with previous findings showing that such experiences on session days predict long-term positive changes in attitudes, mood, behavior, and spirituality (Garcia-Romeu et al., 2014; Griffiths et al., 2008, 2011). For most measures, this relationship continued to be significant when the intensity of overall psilocybin effect was controlled in a partial correlation analysis. This suggests that mystical-type experience per se has an important role apart from overall intensity of drug effect. Finally, a mediation analysis further suggested that mystical-type experience has a mediating role in positive therapeutic response.The observed decreases in psychological distress and anxiety about death may relate to recent epidemiological findings that lifetime psilocybin use was associated with significantly reduced odds of past month psychological distress and suicidality (Hendricks et al., 2015).An innovative feature of the study design was that participants and staff monitors were given instructions that obscured the actual psilocybin dose conditions to facilitate blinding and minimize expectancy effects, which are believed to be a significant determinant of classic hallucinogen effects (Griffiths et al., 2006; Metzner et al., 1965). Evidence of some success of this blinding was provided in a post-study questionnaire completed by staff and by significant treatment effects observed after Session 1 in participants who received the very low dose of psilocybin. Although it was assumed that 1 mg/70 kg would be largely pharmacologically inactive, some pharmacological activity of this dose cannot be ruled out entirely. Thus, this dose might have been preferable to use an even lower dose of psilocybin (e.g. 0.01 mg/70 kg) to assure pharmacological inactivity while maintaining the benefit of the instruction that psilocybin would be administered on each session. Although the lo ...

# %% [markdown]
# ## Step 1:  Named Entity Recognition Model

# %%
# -- Load our fine-tuned named entity model --
nlp = spacy.load('../KGs/model-best')

# %%
# -- Test on one sentence -- 
text = ['This sentence tests whether our NER model can capture psychedelic drugs such as psilocybin, ayahuasca, DMT, and LSD, and also our health conditions such as depression, anxiety, and PTSD. It also looks for outcomes such as positive outcome, reduces depressive symptoms, and perhaps negative outcomes like increased anxiety']

# %%
for doc in nlp.pipe(text, disable=["tagger", "parser"]):
    print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('psychedelic drugs', 'DRUG'), ('psilocybin', 'DRUG'), ('ayahuasca', 'DRUG'), ('DMT', 'DRUG'), ('LSD', 'DRUG'), ('depression', 'HEALTH'), ('anxiety', 'HEALTH'), ('PTSD', 'HEALTH'), ('positive outcome', 'OUTCOME'), ('reduces depressive symptoms', 'OUTCOME'), ('anxiety', 'HEALTH')]
# /home/cds-au604588/KGs/Psychedelic_KG/lib/python3.6/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %% [markdown]
# _Here we see that the model is able to capture our drugs, health conditions, and some outcomes, but incorrectly labels the 'increased anxiety' as we might expect given that it works with accuracy of around 65%._

# %% [markdown]
# ## Run NER across all discussion texts

# %% [markdown]
# __Extract entities with all their positional information__

# %%
# -- Function to extract entities positional information -- 
def extract_ents(documents,nlp):
    #create an empty list object 
    docs = list()
    
    #for each document (discussion) in the model's pipeline, extract the named entities (ignore tagging and parsing)
    for doc in nlp.pipe(documents, disable=["tagger", "parser"]):
        #save the information into a temporary dictionary 
        dictionary=dict.fromkeys(["text", "annotations"])
        #Make the text column into string variables 
        dictionary["text"]= str(doc)
        #use hashlib functionality to make sense of the encrypted texts 
        dictionary['text_sha256'] =  hashlib.sha256(dictionary["text"].encode('utf-8')).hexdigest()
        
        # Create an empty list for annotations from this document to be saved into 
        annotations=[]
        
        #for every entity in the document 
        for e in doc.ents:
            #extract the entity text (i.e., which word has the model picked up on) 
            ent_id = hashlib.sha256(str(e.text).encode('utf-8')).hexdigest()
            #extract the entity labelt he model has given this word
            ent = {"start":e.start_char,"end":e.end_char, "label":e.label_,"label_upper":e.label_.upper(),"text":e.text,"id":ent_id}
            #append these to the annotations list to have text, labels, and positional information 
            annotations.append(ent)
        
        #Add our annotations to the dictionary object we've created and return dictionary 
        dictionary["annotations"] = annotations
        docs.append(dictionary)
        
    return docs

# %%
# -- Run across all the discussions -- 
parsed_ents = extract_ents(discussions,nlp)

# %%
print(f"The parsed entities are type: {type(parsed_ents)}.")
print(f"The columns within parsed ents are type: {type(parsed_ents[0])}.")
print(f"The parsed entities are of length: {len(parsed_ents)}.") # this should be 84 for our 84 documents
# Out:
# The parsed entities are type: <class 'list'>.
# The columns within parsed ents are type: <class 'dict'>.
# The parsed entities are of length: 84.

# %%
# --- inspect instance of output ---
parsed_ents[0]['annotations']
# Out:
# [{'start': 62,
#   'end': 72,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 138,
#   'end': 152,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'depressed mood',
#   'id': 'df85a0d5d82bc34ffe98dd5ded6e904975b70b9b4612bbd3890265035e30a327'},
#  {'start': 157,
#   'end': 164,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 173,
#   'end': 197,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'increase quality of life',
#   'id': 'c0a249d408bf13c1f9c899081488f6febf24fd05e54110e3275456d915899e14'},
#  {'start': 234,
#   'end': 250,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'cancer diagnosis',
#   'id': '1a7804cb3ecf89ae73509bc6fcc2e5222ced57137bbc2b5a71c6232c614c056c'},
#  {'start': 349,
#   'end': 357,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'efficacy',
#   'id': 'c561b3df7bcc7f55069d96e6b5be9c5020405c8dd8d5a2b97647bb2fd4c7be01'},
#  {'start': 378,
#   'end': 388,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 429,
#   'end': 439,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 527,
#   'end': 537,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'depression',
#   'id': '74fd2e753c4e2cd9afcadf0a6667fc47ef068c8a782d50e2f3c3907fc666d4c8'},
#  {'start': 539,
#   'end': 546,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 550,
#   'end': 566,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'mood disturbance',
#   'id': 'e759b065a23612026b62a6f33765c6919f1e66b2c9c8e3d3d9583638a0f448a4'},
#  {'start': 597,
#   'end': 612,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'quality of life',
#   'id': 'cf4bb22c0daa38a7f1ddd37e4bb1686b00a709069068a15fbbe8826e99e8469b'},
#  {'start': 614,
#   'end': 626,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'life meaning',
#   'id': '16a1e673e8d3d1a0788ffce01dbc3b587cc568fdcf22d7a15ff0a7b50533b370'},
#  {'start': 628,
#   'end': 644,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'death acceptance',
#   'id': 'e831c3dddcd49acfbf644f8838ba9d9150643c817188ee770c6a17fe98645f9e'},
#  {'start': 650,
#   'end': 658,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'optimism',
#   'id': 'c9c3722d768c33938b0a250c9e252ae33021f52d40e5e95ac3edd1355501274e'},
#  {'start': 738,
#   'end': 748,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'depression',
#   'id': '74fd2e753c4e2cd9afcadf0a6667fc47ef068c8a782d50e2f3c3907fc666d4c8'},
#  {'start': 753,
#   'end': 760,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 866,
#   'end': 883,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'symptom remission',
#   'id': 'bdcb04016392c54aeb6b5c29c07a0666fd654107ee9175a614c5b296f0400d82'},
#  {'start': 953,
#   'end': 1037,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'positive changes in attitudes about life, self, mood, relationships and spirituality',
#   'id': 'bfcc20df560747579ca956d8377498b1dc0ca364de9c1b4297cc4931394e24a8'},
#  {'start': 1084,
#   'end': 1104,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'increased well-being',
#   'id': '8e60e425263c6c432a219d8bfd7ce45bf4b4e34dbe51d2612f2fea475ab89974'},
#  {'start': 1108,
#   'end': 1125,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'life satisfaction',
#   'id': 'fe448baede63eadd3fe3136b574743d5e0dd5970515ea177f0b308ea593bdbbd'},
#  {'start': 1133,
#   'end': 1149,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'positive effects',
#   'id': 'fa25f572b7716619f4da14f5ab2efa739e10b7dc7e0f3918362798f4579b9e0c'},
#  {'start': 1413,
#   'end': 1423,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 1441,
#   'end': 1456,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'cancer patients',
#   'id': '3833d2989d33afcae1365f45c59137e995abf45402bde4bccf4e5c6323503c4e'},
#  {'start': 1508,
#   'end': 1518,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 1565,
#   'end': 1575,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'depression',
#   'id': '74fd2e753c4e2cd9afcadf0a6667fc47ef068c8a782d50e2f3c3907fc666d4c8'},
#  {'start': 1580,
#   'end': 1587,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 1766,
#   'end': 1776,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 1955,
#   'end': 1979,
#   'label': 'SUBJECTIVE',
#   'label_upper': 'SUBJECTIVE',
#   'text': 'mystical-type experience',
#   'id': 'd8f6523ff9ee4e510454d3a4ffe1b8599a22281aa7bda73029514bd69d44901b'},
#  {'start': 2022,
#   'end': 2070,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'enduring changes in therapeutic outcome measures',
#   'id': '334c431dcc085ca1b22b9f6a9013d0804e7ecfca36182af5e45bcf2c99ad72bb'},
#  {'start': 2187,
#   'end': 2260,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'long-term positive changes in attitudes, mood, behavior, and spirituality',
#   'id': 'b170e03289fcd9bdbdf97a98a5ec492ed04f91214d4ec3341283aab5c8279ce1'},
#  {'start': 2415,
#   'end': 2425,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 2502,
#   'end': 2526,
#   'label': 'SUBJECTIVE',
#   'label_upper': 'SUBJECTIVE',
#   'text': 'mystical-type experience',
#   'id': 'd8f6523ff9ee4e510454d3a4ffe1b8599a22281aa7bda73029514bd69d44901b'},
#  {'start': 2588,
#   'end': 2599,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'drug effect',
#   'id': '024c34268a9f3c889ca1ced5688c805d43826e2a6b21080388fa317f71db2e0f'},
#  {'start': 2654,
#   'end': 2678,
#   'label': 'SUBJECTIVE',
#   'label_upper': 'SUBJECTIVE',
#   'text': 'mystical-type experience',
#   'id': 'd8f6523ff9ee4e510454d3a4ffe1b8599a22281aa7bda73029514bd69d44901b'},
#  {'start': 2685,
#   'end': 2732,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'mediating role in positive therapeutic response',
#   'id': '5b1f1398e0925ee71244adb680f542ef88418c7f14379644c2329770d314d4a4'},
#  {'start': 2759,
#   'end': 2781,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'psychological distress',
#   'id': '3d707cd7cc497ffc610d11170eea48011893eb812a941df2d2663fd7f81d3cee'},
#  {'start': 2786,
#   'end': 2793,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 2866,
#   'end': 2876,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 2942,
#   'end': 2964,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'psychological distress',
#   'id': '3d707cd7cc497ffc610d11170eea48011893eb812a941df2d2663fd7f81d3cee'},
#  {'start': 2969,
#   'end': 2980,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'suicidality',
#   'id': '0ac9dd0c507ea99642e96780b56c833ae3cef23c96390439200db358919dff10'},
#  {'start': 3138,
#   'end': 3148,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 3192,
#   'end': 3219,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'minimize expectancy effects',
#   'id': '535bee098ba6b11c1101f872bfe557d1b3bf8480aaee0ac64ee1e56cd07dfd33'},
#  {'start': 3275,
#   'end': 3303,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'classic hallucinogen effects',
#   'id': '2f1e02a5a425de2c6ee62bcae68034868a584d308c97bf6bfdb48684c3b1dff4'},
#  {'start': 3463,
#   'end': 3492,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'significant treatment effects',
#   'id': '5552041f2ba8ea64daafd36b66cfaea2b4b69ff53d0eea09371b98f766445964'},
#  {'start': 3568,
#   'end': 3578,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 3670,
#   'end': 3694,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'pharmacological activity',
#   'id': '98bf8da29fca227c924357f3048ce79714d6f4a555e3c65a3ed7fb412154a319'},
#  {'start': 3810,
#   'end': 3820,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 3852,
#   'end': 3878,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'pharmacological inactivity',
#   'id': 'cb6e33baa1839bb9061b7d86e852e6c4b6910c39982326a8f8117db360fbffe2'},
#  {'start': 3933,
#   'end': 3943,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 4094,
#   'end': 4122,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'minimized expectancy effects',
#   'id': '4b23baee6e084334354c705303ec4d66989864b00b06e1537bcaff66eca60e4f'},
#  {'start': 4491,
#   'end': 4509,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'persisting effects',
#   'id': '68929856e14d57d21871e8e0f7bab32fc819a95b41f488adcc40a2fa3c92120b'},
#  {'start': 4513,
#   'end': 4523,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 4593,
#   'end': 4601,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'efficacy',
#   'id': 'c561b3df7bcc7f55069d96e6b5be9c5020405c8dd8d5a2b97647bb2fd4c7be01'},
#  {'start': 4622,
#   'end': 4632,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 4728,
#   'end': 4788,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'enduring increases in positive changes in attitudes and mood',
#   'id': '8adb96a4f0bbc23b12c85f689a9c7b2e15b9b40da05c3928bb04e2a4c9fbd843'},
#  {'start': 5026,
#   'end': 5036,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'depression',
#   'id': '74fd2e753c4e2cd9afcadf0a6667fc47ef068c8a782d50e2f3c3907fc666d4c8'},
#  {'start': 5041,
#   'end': 5048,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 5401,
#   'end': 5438,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'cancer-related psychological distress',
#   'id': '1191ec91552fbc81837a2610acf3dac08f1c8192fdad1a7809829d1f49042e26'},
#  {'start': 5444,
#   'end': 5454,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 5637,
#   'end': 5647,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 5749,
#   'end': 5759,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 5796,
#   'end': 5840,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'transient episodes of psychological distress',
#   'id': 'b852e0f53d2edbe234a0875ec6ad170d0dbfca5717f46940a63d71ae458e8e7a'},
#  {'start': 5844,
#   'end': 5851,
#   'label': 'HEALTH',
#   'label_upper': 'HEALTH',
#   'text': 'anxiety',
#   'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#  {'start': 5909,
#   'end': 5919,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 5920,
#   'end': 5939,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'therapeutic effects',
#   'id': 'f2131c3ba877e59fcc82d85a03c4cde78df4f81401e3c0ddc240caa27f56a995'},
#  {'start': 5964,
#   'end': 5978,
#   'label': 'NEURAL',
#   'label_upper': 'NEURAL',
#   'text': '5-HT2A agonist',
#   'id': '647049ea5716c824a14a278665d42a89c3bb94a48b15c93d885acb7e90d181b5'},
#  {'start': 5984,
#   'end': 5994,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocybin',
#   'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#  {'start': 6006,
#   'end': 6014,
#   'label': 'DRUG',
#   'label_upper': 'DRUG',
#   'text': 'psilocin',
#   'id': '9763a414fea533824db3113edfca4cde2ee5695ad2fa85d0c2fe43508f82fc91'},
#  {'start': 6055,
#   'end': 6091,
#   'label': 'NEURAL',
#   'label_upper': 'NEURAL',
#   'text': 'brain cortical and subcortical areas',
#   'id': '2e88bc6ac0cc84003685f4934141b67a7f236cc8b72db673a5f949aa9159cdf1'},
#  {'start': 6096,
#   'end': 6125,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'alters brain network dynamics',
#   'id': 'a079bc072a9dbdc36b9cc33be1d87290cea0f26452d41fcc334711c77537ebec'},
#  {'start': 6144,
#   'end': 6196,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'enduring therapeutically relevant psilocybin effects',
#   'id': '1adcc563213933a90f614f1889e25cd47af559a67ed4f5314da45b58638a6aed'},
#  {'start': 6214,
#   'end': 6255,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'long-term alteration of cortical networks',
#   'id': 'c736bf217b9f2357dd0c3cf0f9da403e283436f77e5f02c14bfeca6e2cef8543'},
#  {'start': 6265,
#   'end': 6285,
#   'label': 'OUTCOME',
#   'label_upper': 'OUTCOME',
#   'text': 'neuroplastic changes',
#   'id': 'f0e1fe4da83e3e4cfeaab89f87d40d28efe957e991888e63a932ccc215dfc991'}]

# %%
parsed_ents[1]
# Out:
# {'text': "The initial goals of this research project were to establish feasibility and safety for a hallucinogen treatment model in patients with advanced-stage cancer and anxiety. Following discussion with federal and state regulatory agencies as well as hospital institutional review board and research committees, a modest 0.2-mg/kg psilocybin dose was chosen. Although not comparable to higher doses of hallucinogens administered in the past to severely ill patients, the dose used here was still believed capable of inducing an alteration of consciousness with potential therapeutic benefit while optimizing patient safety. Determining safe parameters with this novel treatment paradigm is critical to establishing a strong foundation for this field of study that would allow for future investigations. Consistent with previous research, we found no untoward cardiovascular sequelae in we subject population.19 Minor HR and BP elevations after psilocybin administration were evidence only of a mild sympathomimetic effect. Holter monitoring did not identify increased cardiac arrhythmias in comparison with niacin placebo, even in subjects who presented with some baseline cardiac arrhythmia. Niacin may acutely lower BP through vasodilation35 but had minimal effects on BP and HR in our subjects, except for a reduction in diastolic BP that was noted 1 hour after administration of niacin. This transient effect may have contributed to our detection of a significant psilocybin effect at that time but cannot explain the significant effects of psilocybin over the subsequent intervals because the initial niacin-induced reduction of diastolic BP did not persist. We also observed no adverse psychological effects from the treatment. All subjects tolerated the treatment sessions well, with no indication of severe anxiety or a “bad trip.” The fact that psilocybin produced only modest effects on the anxious ego dissolution scale of the 5D-ASC confirmed this conclusion. When hallucinogens were administered to patients with terminal cancer in the 1960s and early 1970s, the occurrence of a profound psychospiritual experience was correlated with therapeutic outcome.10,12 Such transcendent states of consciousness are usually associated with higher doses of hallucinogens, so our expectation of demonstrating efficacy was limited.21 Common themes reported by subjects included examining how Common illness had impacted Common lives, relationships with family and close friends, and sense of ontological security. In addition, subjects reported powerful empathic cathexis to close friends and family members and examined how subjects wished to address subjects limited life expectancy. In monthly follow-up discussions, subjects reflected on insights and new perspectives gained during subjects psilocybin treatment. However, the frequency of these reports was not quantified. Although past researchers reported more pronounced therapeutic effects with a higher-dose model, even the lower dose of psilocybin used in the current study gave some indication of therapeutic benefit in quantitative psychological evaluations. In particular, we found that the STAI trait anxiety subscale demonstrated a sustained reduction in anxiety that reached significance at the 1- and 3-month points after treatment. This reduction might reflect a reduced level of stress and anxiety over time. Although the state anxiety on the STAI showed a modest elevation at 6 months, the change was not statistically significant and might have resulted from the deteriorating medical status of most subjects over time. Mood also improved for 2 weeks after treatment with psilocybin, with sustained improvement on the BDI reaching significance at the 6-month follow-up point. The POMS scores also reflected improved mood 2 weeks after receiving psilocybin. Although not statistically significant, there was a trend toward positive outcome. With a larger cohort of subjects and use of a higher dose of psilocybin, it seems p ...
#  'annotations': [{'start': 90,
#    'end': 102,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogen',
#    'id': 'e8b5d02932357d271f646bf37f4d0c054d569987fea614b72f0388c7c12b3c9d'},
#   {'start': 136,
#    'end': 157,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'advanced-stage cancer',
#    'id': 'ca0c02b78dc501b7072942278d74f765fdcb30786a2cffec676045906f72db58'},
#   {'start': 162,
#    'end': 169,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 326,
#    'end': 336,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 397,
#    'end': 410,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogens',
#    'id': '56b8673f2be6cf1f9afee47bb1bad83e47b7a8d4ae5014cddb7a47537a8cd776'},
#   {'start': 511,
#    'end': 585,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'inducing an alteration of consciousness with potential therapeutic benefit',
#    'id': 'ec3f58b36d5ba2b028b16c306427945009d9f76c533adabe933790e62c8190d0'},
#   {'start': 592,
#    'end': 617,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'optimizing patient safety',
#    'id': '77686e69ac7faad37e9d0b269e2ff73bf7abcc65f1402a65ad1aa6c91d87f3ec'},
#   {'start': 842,
#    'end': 877,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'no untoward cardiovascular sequelae',
#    'id': '216055d601da88991ea82c2cb49d83f86b06e423d3fc940a8495265c3fd71149'},
#   {'start': 906,
#    'end': 932,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'Minor HR and BP elevations',
#    'id': '83afe7c186ae65687362dbc51fc0309a22b39491894a46298b76499edfdbf619'},
#   {'start': 939,
#    'end': 949,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 989,
#    'end': 1016,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'mild sympathomimetic effect',
#    'id': '522c915449305683e360196115eddbdaf5b29cf702bdd8edfac88db1295dd4a2'},
#   {'start': 1053,
#    'end': 1082,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'increased cardiac arrhythmias',
#    'id': 'cdaa0150a232da3a484dc5ea774c0ee9c602386d58164b94adf09a64da7dc490'},
#   {'start': 1168,
#    'end': 1186,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'cardiac arrhythmia',
#    'id': 'fb86038ecada1c41217aa27b2d07009a2847d09a8c5a5f0086cafd4748d76a9a'},
#   {'start': 1247,
#    'end': 1262,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'minimal effects',
#    'id': 'b463e9d61a27405a1ecd74f4369d57165d774b4d4b3568044962916d9dbecb19'},
#   {'start': 1306,
#    'end': 1331,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'reduction in diastolic BP',
#    'id': '4fbb5b450cb63a14491706e41a6a06d9295e84775f09f3038e9f4d6ccdcf0790'},
#   {'start': 1391,
#    'end': 1407,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'transient effect',
#    'id': '74e693df95d2da78bb8248b8130fe6cc139734a1acddc380779f7225e2e265bb'},
#   {'start': 1451,
#    'end': 1480,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'significant psilocybin effect',
#    'id': '21a14f4ad1526b7f6f503fc985857ca79d312d8105b996a7553c78f6c1b2dba2'},
#   {'start': 1517,
#    'end': 1536,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'significant effects',
#    'id': '0541a9e74c36ffe7b2ad9eef8c54e696bae16321e5f8cd76b5078c9bce8dc9b6'},
#   {'start': 1540,
#    'end': 1550,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 1601,
#    'end': 1657,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'niacin-induced reduction of diastolic BP did not persist',
#    'id': 'acb84fe8573088b40704373432af356f9762713a60dfb43381d722a5351fef2d'},
#   {'start': 1679,
#    'end': 1708,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'adverse psychological effects',
#    'id': '7dabc556d6edc0acb54834ba63d535172c6b29afc75af3afcf760da89540018b'},
#   {'start': 1742,
#    'end': 1779,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'tolerated the treatment sessions well',
#    'id': '4af7a83f79e691b7f413e4df306c75db5013ba7dad52c8541bd1466adefef355'},
#   {'start': 1810,
#    'end': 1817,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 1824,
#    'end': 1832,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'bad trip',
#    'id': 'ec7682cbfd8c72cc1b49fdc6533365c44575a7383056d39ff480d7a695ef2a48'},
#   {'start': 1849,
#    'end': 1859,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 1874,
#    'end': 1888,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'modest effects',
#    'id': '018ad0eeb39a4a12d7ed3240037bfd469c5ca2905668c29c32761c48b7fc0b65'},
#   {'start': 1904,
#    'end': 1919,
#    'label': 'SUBJECTIVE',
#    'label_upper': 'SUBJECTIVE',
#    'text': 'ego dissolution',
#    'id': '081a72509559a496bedd7f4b99bd42b45f7830419470d514e1f9c28a0ca2943a'},
#   {'start': 1972,
#    'end': 1985,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogens',
#    'id': '56b8673f2be6cf1f9afee47bb1bad83e47b7a8d4ae5014cddb7a47537a8cd776'},
#   {'start': 2021,
#    'end': 2036,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'terminal cancer',
#    'id': 'e73dbde5d905af581a7f522bd488eddd983f4eacb0aa0c95633697af8dac0874'},
#   {'start': 2087,
#    'end': 2122,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'profound psychospiritual experience',
#    'id': 'fa13913f664e08d444d9cac6bded689812fe708b7c8681445148b2cdee9d8f14'},
#   {'start': 2143,
#    'end': 2168,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'therapeutic outcome.10,12',
#    'id': '9aaa24667e5882a81b3d91eeb3f465da7fda1f87ebdafbf76a42d2933c098acb'},
#   {'start': 2174,
#    'end': 2210,
#    'label': 'SUBJECTIVE',
#    'label_upper': 'SUBJECTIVE',
#    'text': 'transcendent states of consciousness',
#    'id': 'c6277362557e5363750a744d4622b055ec511daa1656cf78cb95a744d260ceea'},
#   {'start': 2255,
#    'end': 2268,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogens',
#    'id': '56b8673f2be6cf1f9afee47bb1bad83e47b7a8d4ae5014cddb7a47537a8cd776'},
#   {'start': 2306,
#    'end': 2314,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'efficacy',
#    'id': 'c561b3df7bcc7f55069d96e6b5be9c5020405c8dd8d5a2b97647bb2fd4c7be01'},
#   {'start': 2374,
#    'end': 2428,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'examining how Common illness had impacted Common lives',
#    'id': '5f1ffd6e7eba1c20af2449207611419cb6ac4687d6645415f998e7e3f3f72733'},
#   {'start': 2430,
#    'end': 2473,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'relationships with family and close friends',
#    'id': '90218c9e1b1b5f7fe29949d1a120499f332a092d0d71c314fff3b5e293be5835'},
#   {'start': 2479,
#    'end': 2508,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'sense of ontological security',
#    'id': 'a5c0024d7011dde4306671f2294e68fa6a4bbf0c75696303fbbf654f4e386fed'},
#   {'start': 2541,
#    'end': 2603,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'powerful empathic cathexis to close friends and family members',
#    'id': 'c2d1b321404e8cd9a92c35429c01db6fa879799b91516c0696955e778cfe021a'},
#   {'start': 2617,
#    'end': 2680,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'how subjects wished to address subjects limited life expectancy',
#    'id': '847cac7916571a3f231f956cfc4e992aca70da8852278cfb0499d51e17377f02'},
#   {'start': 2751,
#    'end': 2774,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'new perspectives gained',
#    'id': '27a7230db6c47aca44e87855e6803c5d7c829d841bbd1b7a87ff0092880651cf'},
#   {'start': 2791,
#    'end': 2801,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 2913,
#    'end': 2943,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'pronounced therapeutic effects',
#    'id': '174c16cc6f6c6c8782bd11b9d6f4dcb26392f46c5551986da13cd65877bfae1c'},
#   {'start': 2993,
#    'end': 3003,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 3054,
#    'end': 3073,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'therapeutic benefit',
#    'id': 'b9ff31ed6a721f71d95e752972ee473080fadf5606706053ba6215cebea6cd21'},
#   {'start': 3161,
#    'end': 3168,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 3216,
#    'end': 3223,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 3344,
#    'end': 3350,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'stress',
#    'id': 'f43dc8790ed6215684924d362753e3864cb66c0f06084e89ad36b57e15986c6e'},
#   {'start': 3355,
#    'end': 3362,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 3393,
#    'end': 3400,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'anxiety',
#    'id': 'ab0231f72dd9f07809f05d962bfc823a935461a2f194cc1b3be51dae6670836e'},
#   {'start': 3587,
#    'end': 3591,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'Mood',
#    'id': '780fe43f6e8bdc250db49ec311e992329b599e783c41ae8f9a5a43d90c37f9b6'},
#   {'start': 3639,
#    'end': 3649,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 3783,
#    'end': 3787,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'mood',
#    'id': 'ee0e4f309c9a47317d3344b5bcd25dcbf0727a91833d5c6e21b842b53c406878'},
#   {'start': 3812,
#    'end': 3822,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 3889,
#    'end': 3905,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'positive outcome',
#    'id': '14dbd063b94593d7aa1c7ff07e07178863affc249388b727e3aca7c06b736231'},
#   {'start': 3968,
#    'end': 3978,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 4151,
#    'end': 4161,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 4545,
#    'end': 4555,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 4697,
#    'end': 4707,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 4746,
#    'end': 4756,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 4766,
#    'end': 4788,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'mood-elevating effects',
#    'id': 'aabbecb08eed83a6f065abc94d0aff4837044338c700dab3d57592fd317bd95a'},
#   {'start': 4896,
#    'end': 4906,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 5019,
#    'end': 5055,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'robust reductions in pain perception',
#    'id': '29a888c30e7a692240e2d981fd6c821da548b677e81d1cb3c3ae0a70fffa8fb3'},
#   {'start': 5059,
#    'end': 5101,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'lessened need for narcotic pain medication',
#    'id': '58375da911398be0a7054a399570088a8c5841a6b023ce8f8aadf5307475321a'},
#   {'start': 5187,
#    'end': 5200,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'lessened pain',
#    'id': '19825383366204eb8e19e3ebdd1f0f8ccafe30765af52641531786cb960cc3e8'},
#   {'start': 5289,
#    'end': 5299,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 5378,
#    'end': 5388,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 5416,
#    'end': 5420,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'pain',
#    'id': '5c78c8e7160e76ba9b6c41f74247bb7ba4887f5c06faecd6b9a009785b248c72'},
#   {'start': 5721,
#    'end': 5731,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 5811,
#    'end': 5892,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'placebo sessions were perceived as far less worthwhile than those with psilocybin',
#    'id': 'c0f15bd9611d2e2382b794169b842e911b4a2a39e89acfae689a242dae29062e'},
#   {'start': 5984,
#    'end': 5994,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 6108,
#    'end': 6118,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 6160,
#    'end': 6179,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'therapeutic effects',
#    'id': 'f2131c3ba877e59fcc82d85a03c4cde78df4f81401e3c0ddc240caa27f56a995'},
#   {'start': 7026,
#    'end': 7036,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 7064,
#    'end': 7088,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'strong therapeutic bonds',
#    'id': 'c3e7d8538119e072f544ddbb8ef01d3699b1abcb1068697ed66cd95b211ef405'},
#   {'start': 7093,
#    'end': 7145,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'ameliorating underlying psychological demoralization',
#    'id': '77063acee7a6ad7b4c039450192ff1f3f83ab9f92963a0e3c3f4314bacbe57e7'},
#   {'start': 7622,
#    'end': 7632,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 7648,
#    'end': 7733,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'alternative model for the treatment of conditions that are often minimally responsive',
#    'id': 'e4485abccded5701875739edbe00053aaff052c1d418ad2e4ae9362d7ea930a5'},
#   {'start': 7784,
#    'end': 7803,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'existential anxiety',
#    'id': '60e7a4d5c92041468f8dd9c1f9ec1090ce5dae55440fee66040b7c64e1b23285'},
#   {'start': 7808,
#    'end': 7815,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'despair',
#    'id': 'e7684586cdf72449493234ec76303972e86fe3d7ad824c8bfa520b45135ef559'},
#   {'start': 7837,
#    'end': 7859,
#    'label': 'HEALTH',
#    'label_upper': 'HEALTH',
#    'text': 'advanced-stage cancers',
#    'id': '8f3dee699d0d3b02a2f4d20fffc1c300f87a51836e1613059007fe7fa57c1bc4'},
#   {'start': 7886,
#    'end': 7896,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'},
#   {'start': 8015,
#    'end': 8027,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogen',
#    'id': 'e8b5d02932357d271f646bf37f4d0c054d569987fea614b72f0388c7c12b3c9d'},
#   {'start': 8237,
#    'end': 8255,
#    'label': 'OUTCOME',
#    'label_upper': 'OUTCOME',
#    'text': 'safety and promise',
#    'id': '80fc27eef5448739f5870d8f23a1dc9f8f09fd6a6378fa400ae1ff71146a65c4'},
#   {'start': 8321,
#    'end': 8345,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'hallucinogenic compounds',
#    'id': 'ba20fb6e8dbb4ab6eec8a2ee3614b36f32b99681d1bb8af2a13dc126e977ab81'},
#   {'start': 8354,
#    'end': 8364,
#    'label': 'DRUG',
#    'label_upper': 'DRUG',
#    'text': 'psilocybin',
#    'id': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95'}],
#  'text_sha256': '9a11e128760948c78f95d7f0d9f5369790b83f686c75aef444d9e5c7429c6ff6'}

# %% [markdown]
# #### Save the parsed ents

# %%
# -- Save as pickled object for loading into colab -- 
with open('4_Knowledge_Graphs/output/parsed_ents.pickle', 'wb') as f:
    pickle.dump(parsed_ents, f)

# %%
#  -- Check the types remain the same when re-loaded 
with open('4_Knowledge_Graphs/output/parsed_ents.pickle', 'rb') as f:
     test= pickle.load(f)

# %%
print(f"The parsed entities are type: {type(test)}.")
print(f"The columns within parsed ents are type: {type(test[0])}.")
print(f"The parsed entities are of length: {len(test)}.")
# Out:
# The parsed entities are type: <class 'list'>.
# The columns within parsed ents are type: <class 'dict'>.
# The parsed entities are of length: 84.

# %% [markdown]
# _All looks good!_

# %%
# --- save the output as a csv file --- 
keys = parsed_ents[5].keys()

parsed_entities = open("4_Knowledge_Graphs/output/parsed_entities.csv", "w")
dict_writer = csv.DictWriter(parsed_entities, keys)
dict_writer.writeheader()
dict_writer.writerows(parsed_ents)
parsed_entities.close()

# %%
# -- inspect saved csv file -- 
inspection = pd.read_csv('4_Knowledge_Graphs/output/parsed_entities.csv')
inspection[:3]
# Out:
#                                                 text  \
# 0  The present study demonstrated the efficacy of...
# 1  The initial goals of this research project wer...
# 2  Dr. Albert Hofmann, the natural products chemi...
#
#                                          annotations  \
# 0  [{'start': 62, 'end': 72, 'label': 'DRUG', 'la...
# 1  [{'start': 90, 'end': 102, 'label': 'DRUG', 'l...
# 2  [{'start': 90, 'end': 93, 'label': 'DRUG', 'la...
#
#                                          text_sha256
# 0  f624d5abadc6418f41ea425eb53506e811e19f239c7681...
# 1  9a11e128760948c78f95d7f0d9f5369790b83f686c75ae...
# 2  ac9c65712e00a2d59a49e1f0b04580c9e8adeeae5bb32e...

# %% [markdown]
# __More simple parsing: Extract entities to include only their entity text and label__

# %%
# --- more simple parsing --- 
article_word = []
article_label = []


for doc in nlp.pipe(discussions, disable=["tagger", "parser"]):
    for ent in doc.ents:
        text = ent.text
        article_word.append(text)
        
        label = ent.label_
        article_label.append(label)

# %%
print(f"There are {len(article_word)} entities extracted across the 84 documents.")
print(f"There are {len(article_label)} labels extracted for these entities.")
# Out:
# There are 9903 entities extracted across the 84 documents.
# There are 9903 labels extracted for these entities.

# %%
# -- Create a list of the text and labels --
def merge(list1, list2):
      
    merged_list = []
    for i in range(max((len(list1), len(list2)))):
  
        while True:
            try:
                tup = (list1[i], list2[i])
            except IndexError:
                if len(list1) > len(list2):
                    list2.append('')
                    tup = (list1[i], list2[i])
                elif len(list1) < len(list2):
                    list1.append('')
                    tup = (list1[i], list2[i])
                continue
  
            merged_list.append(tup)
            break
    return merged_list

# %%
tuple_list = merge(article_word, article_label)
print(f"\ntuple_list is a type: {type(tuple_list)}.")
print(f"\ntuple_list is length: {len(tuple_list)}.")
# Out:
# tuple_list is a type: <class 'list'>.
#
# tuple_list is length: 9903.

# %%
tuple_list[:3]
# Out:
# [('psilocybin', 'DRUG'), ('depressed mood', 'HEALTH'), ('anxiety', 'HEALTH')]

# %%
# -- save the list of tuples -- 
with open("4_Knowledge_Graphs/output/entity_labels.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(zip(article_word, article_label))

# %% [markdown]
# ## Step 2: Connect the NER with Relation Extraction

# %%
# -- import the necessary dependencies -- 
import random
import typer
from pathlib import Path
import spacy
from spacy.tokens import DocBin, Doc
from spacy.training.example import Example

# %%
# -- extract the functions from our created model in the rel_component folder -- 
from rel_component.scripts.rel_pipe import make_relation_extractor, score_relations

# %%
# -- extract necessary functions from our config folder -- 
from rel_component.scripts.rel_model import create_relation_model, create_classification_layer, create_instances, create_tensors

# %%
# -- load the Relation extraction model --
nlp2 = spacy.load("../KGs/rel_component/training/model-best")

# %% [markdown]
# ### Extract relationships

# %%
# -- function to extract our relations -- 
def extract_relations(documents,nlp,nlp2):
    # create an empty list to save the extracted info into 
    predicted_rels = list()
    
    # for every psychedelic article, we want to take the ner elements
    for doc in nlp.pipe(documents, disable=["tagger", "parser"]):
        #Then create an understandable hash tag which can be used to identify the entities (like an id number)
        source_hash = hashlib.sha256(doc.text.encode('utf-8')).hexdigest()
        
        #initiate the doc objects from the relation extraction pipeline 
        for name, proc in nlp2.pipeline:
              doc = proc(doc)
        
        #then for each value and relation dictionary in the doc object 
        for value, rel_dict in doc._.rel.items():
            #extract the first entity
            for e in doc.ents:
                #and also the second entity
                for b in doc.ents:
                    #see if the entities match 
                    if e.start == value[0] and b.start == value[1]:
                        #classify the relationships
                        max_key = max(rel_dict, key=rel_dict. get)
                        
                        #extract the unique ids for each entity 
                        e_id = hashlib.sha256(str(e).encode('utf-8')).hexdigest()
                        b_id = hashlib.sha256(str(b).encode('utf-8')).hexdigest()
                        #if the relationship probability is higher than 90% then store it in the predicted rels list
                        if rel_dict[max_key] >=0.9 :
                            predicted_rels.append({'head': e_id, 'tail': b_id, 'type':max_key, 'source': source_hash})
    return predicted_rels

# %% [markdown]
# _Beware the below code takes ~2hrs to run_

# %%
psychedelic_relationships = extract_relations(discussions,nlp,nlp2)

# %%
# -- check how many relationships have been classified -- 
len(psychedelic_relationships)
# Out:
# 3348

# %%
# -- inspect the relationships -- 
psychedelic_relationships[501:506] # remember our nodes are in this hashlib source langauge
# Out:
# [{'head': '062e0d8b0394241db98b94a14a411158c5cb469f6ebb300dd7c0003c00253b75',
#   'tail': 'd6ef29ea86f326d5337f7f2de9a90c84688dadedb339dcfdb0b6582e3965a04a',
#   'type': 'THOUGHT TO CAUSE',
#   'source': '6cc23b09fa92f4cb146e4331836d768828cde4c7dfb338f687823040ba941ab7'},
#  {'head': '062e0d8b0394241db98b94a14a411158c5cb469f6ebb300dd7c0003c00253b75',
#   'tail': '96e05a77d6248d9ef953df9234112c4128d2624cbcdb1682019783fda7c84cb0',
#   'type': 'THOUGHT TO CAUSE',
#   'source': '6cc23b09fa92f4cb146e4331836d768828cde4c7dfb338f687823040ba941ab7'},
#  {'head': '062e0d8b0394241db98b94a14a411158c5cb469f6ebb300dd7c0003c00253b75',
#   'tail': 'be2a9e82fe321a0ea50d7e8a92f148f272302f0a862bcdebba7d459d7322d7c8',
#   'type': 'THOUGHT TO CAUSE',
#   'source': '6cc23b09fa92f4cb146e4331836d768828cde4c7dfb338f687823040ba941ab7'},
#  {'head': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95',
#   'tail': 'd5c9f01aec1fa5708b3c9bdeee3d0468721d2b8aab55ee1b20013213a674520a',
#   'type': 'POSITIVELY IMPACTS',
#   'source': '6cc23b09fa92f4cb146e4331836d768828cde4c7dfb338f687823040ba941ab7'},
#  {'head': '55b804e1155b33b0b6cb16e81ec7dd406e046cb731d4e0334accd777990d9c95',
#   'tail': 'f0e393696f1551ddfab976cadbd2e4e28480a07d253220410010887903e08bee',
#   'type': 'POSITIVELY IMPACTS',
#   'source': '6cc23b09fa92f4cb146e4331836d768828cde4c7dfb338f687823040ba941ab7'}]

# %% [markdown]
# #### Getting more meaningful output than simply entity ID

# %%
# --- Function to visualise the entities ---
def extract_relations_visualisation(documents,nlp,nlp2):
    predicted_rels = list()
    for doc in tqdm(nlp.pipe(documents, disable=["tagger", "parser"])):
        source_hash = hashlib.sha256(doc.text.encode('utf-8')).hexdigest()
        for name, proc in nlp2.pipeline:
              doc = proc(doc)

        for value, rel_dict in doc._.rel.items():
            for e in doc.ents:
                for b in doc.ents:
                    if e.start == value[0] and b.start == value[1]:
                        max_key = max(rel_dict, key=rel_dict. get)
            #print(max_key)
                        e_id = hashlib.sha256(str(e).encode('utf-8')).hexdigest()
                        b_id = hashlib.sha256(str(b).encode('utf-8')).hexdigest()
                        if rel_dict[max_key] >=0.9 :
                            #print(f" entities: {e.text, b.text} --> predicted relation: {rel_dict}")
                            predicted_rels.append({'entity 1': e.text, 'entity 1 label': e.label_, 'entity 2': b.text, 'entity 2 label': b.label_, 'type':max_key, 'source': source_hash})
    return predicted_rels

# %%
# --- Apply to the full dataset to get list of dictionaries --- 
relations = extract_relations_visualisation(discussions, nlp, nlp2)
# Out:
# 84it [1:26:56, 62.10s/it]

# %%
# -- inspect relations -- 
print(f"There are {len(relations)} relations detected within the discussions.")
print(f"These are of type {type(relations)}, where each row is a {type(relations[0])}.")
print(f"An example of our dictionary is:\n {relations[:1]}")
# Out:
# There are 3348 relations detected within the discussions.
# These are of type <class 'list'>, where each row is a <class 'dict'>.
# An example of our dictionary is:
#  [{'entity 1': 'psilocybin', 'entity 1 label': 'DRUG', 'entity 2': 'psychological distress', 'entity 2 label': 'OUTCOME', 'type': 'POSITIVELY IMPACTS', 'source': 'f624d5abadc6418f41ea425eb53506e811e19f239c768100097c78295dadf858'}]

# %%
# -- Convert our list of dictionaries into a dataframe 
relations_df = pd.DataFrame(relations)

# %%
relations_count = relations_df.groupby('type').count()
relations_count['entity 1']
# Out:
# type
# NEEDS MORE RESEARCH BETWEEN       205
# NEGATIVELY IMPACTS                 55
# NO RELATIONSHIP FOUND BETWEEN      37
# POSITIVELY IMPACTS               2620
# THOUGHT TO CAUSE                  431
# Name: entity 1, dtype: int64

# %% [markdown]
# _We can see that our model is over estimating the impact of 'positively impacts' and giving almost no attention to the 'negatively impacts' column. This is likely because the model was fed an uneven amount of data, where there was significantly more instances of 'positively impacts' within the data and also because of the contrasts between. This makes us skeptical of our outcomes, but we'll proceed for now to see if we can still extract meaningful insights._

# %% [markdown]
# #### Save the relations information

# %%
# --- Save as a pickle file for reloading ---
with open('4_Knowledge_Graphs/output/relations_pickled.pickle', 'wb') as f:
    pickle.dump(relations, f)

# %%
#  -- Check the types remain the same when re-loaded 
with open('4_Knowledge_Graphs/output/relations_pickled.pickle', 'rb') as f:
     rel_test= pickle.load(f)

# %%
print(f"The rel_test is len: {len(rel_test)}.")
print(f"The rel_test is type: {type(rel_test)}.")
print(f"The rel_test has variables of type: {type(rel_test[0])}.")
# Out:
# The rel_test is len: 3348.
# The rel_test is type: <class 'list'>.
# The rel_test has variables of type: <class 'dict'>.

# %%
# -- Save a more readable csv file also -- 
relations_df.to_csv('4_Knowledge_Graphs/output/relations_df.csv')

# %% [markdown]
# _Please move to the 'Creating_Knowledge_Graphs.ipynb' file to inspect the creation of the knowledge graphs_
