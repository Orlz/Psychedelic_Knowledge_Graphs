# %% [markdown]
# # Preprocessing the Metadata

# %% [markdown]
# Some nice description

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Dependencies

# %%
# ----- GENERAL DEPENDENCIES ----- #
#operating system 
import os 
import sys
sys.path.append(os.path.join(".."))

#File paths and time-keeping 
import glob
from tqdm import tqdm

#Text processing and plotting 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Paths

# %%
# --- Output directory ---
output_directory = "../out/"

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# %%
# --- Data path --- 
data_path = '../data/meta_data/'

# %% [markdown]
# #### Load in the Metadata

# %%
metadata = pd.read_csv(data_path + "full_cohort_meta_cleaned.csv", index_col=0)

# %%
# view
print(len(metadata))
metadata[:5]
# Out:
# 84
#                                              Authors  \
# 1  Griffiths, RR; Johnson, MW; Carducci, MA; Umbr...
# 2  Grob, CS; Danforth, AL; Chopra, GS; Hagerty, M...
# 3                                        Nichols, DE
# 4  Carhart-Harris, RL; Bolstridge, M; Rucker, J; ...
# 5  Carhart-Harris, RL; Erritzoe, D; Williams, T; ...
#
#                                    Author.Full.Names  \
# 1  Griffiths, Roland R.; Johnson, Matthew W.; Car...
# 2  Grob, Charles S.; Danforth, Alicia L.; Chopra,...
# 3                                  Nichols, David E.
# 4  Carhart-Harris, Robin L.; Bolstridge, Mark; Ru...
# 5  Carhart-Harris, Robin L.; Erritzoe, David; Wil...
#
#                                        Article.Title  \
# 1  Psilocybin produces substantial and sustained ...
# 2  Pilot Study of Psilocybin Treatment for Anxiet...
# 3                                       Psychedelics
# 4  Psilocybin with psychological support for trea...
# 5  Neural correlates of the psychedelic state as ...
#
#                                         Source.Title Language Document.Type  \
# 1                      JOURNAL OF PSYCHOPHARMACOLOGY  English       Article
# 2                     ARCHIVES OF GENERAL PSYCHIATRY  English       Article
# 3                            PHARMACOLOGICAL REVIEWS  English        Review
# 4                                  LANCET PSYCHIATRY  English       Article
# 5  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCE...  English       Article
#
#                                      Author.Keywords  \
# 1  Psilocybin; hallucinogen; cancer; anxiety; dep...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  default mode network; hallucinogens; serotonin...
#
#                                        Keywords.Plus  \
# 1  QUALITY-OF-LIFE; MYSTICAL EXPERIENCE QUESTIONN...
# 2                                      PSYCHOTHERAPY
# 3  LYSERGIC-ACID DIETHYLAMIDE; SEROTONIN 5-HT2A R...
# 4   LYSERGIC-ACID DIETHYLAMIDE; 5-HT2A RECEPTOR; LSD
# 5  MEDIAL PREFRONTAL CORTEX; MYSTICAL-TYPE EXPERI...
#
#                                             Abstract  \
# 1  Cancer patients often develop chronic, clinica...
# 2  Context: Researchers conducted extensive inves...
# 3  Psychedelics (serotonergic hallucinogens) are ...
# 4  Background Psilocybin is a serotonin receptor ...
# 5  Psychedelic drugs have a long history of use i...
#
#                    Email.Addresses  ...  Publication.Date  Publication.Year  \
# 1                  rgriff@jhmi.edu  ...                12              2016
# 2               cgrob@labiomed.org  ...                 1              2011
# 3                drdave@purdue.edu  ...                 4              2016
# 4  r.carhart-harris@imperial.ac.uk  ...                 7              2016
# 5            d.nutt@imperial.ac.uk  ...                 2              2012
#
#                                   DOI  Book.DOI   Pubmed.Id  \
# 1            10.1177/0269881116675513       NaN  27909165.0
# 2  10.1001/archgenpsychiatry.2010.116       NaN  20819978.0
# 3               10.1124/pr.115.011478       NaN  26841800.0
# 4       10.1016/S2215-0366(16)30065-7       NaN  27210031.0
# 5             10.1073/pnas.1119598109       NaN  22308440.0
#
#                    Open.Access.Designations  Highly.Cited.Status  \
# 1                   hybrid, Green Published                    Y
# 2                                    Bronze                    Y
# 3                   Bronze, Green Published                    Y
# 4  Green Published, Green Submitted, hybrid                    Y
# 5                   Bronze, Green Published                    Y
#
#    Hot.Paper.Status Publication.Month        Date
# 1                 N               Dec  2016-12-01
# 2                 N               Jan  2011-01-01
# 3                 N               Apr  2016-04-01
# 4                 N               Jul  2016-07-01
# 5                 N               Feb  2012-02-01
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Extract list of author names

# %% [markdown]
# #### Get the author names into a list of individual authors

# %%
# --- Extract the author name column --- 
authors = metadata['Author.Full.Names']

# %%
# --- check the datatypes --- 
print(type(authors))
print(len(authors))

# %%
# --- convert series to list --- 
authors = authors.values.tolist()
print(type(authors))
print(len(authors))

# %%
# --- inspect authors of one paper --- 
authors[0]

# %%
# --- split into individual authors ---
authors_split = []

for row in authors:
    split_authors = row.split(';')
    for author in split_authors:
        authors_split.append(author)

# %%
print(f"There are {len(authors_split)} authors withint the research papers.\n")
authors_split[:10]

# %% [markdown]
# #### Reverse the author names
#
# _We're doing this because it's more typical to find a first name followed by a sirname in news articles_

# %%
# --- reverse the author names (to have first name, then sirname) --- 
author_names = []

for author in authors_split:
    author_name = author.split(',')
    name_reversed = author_name[1] + ' ' + author_name[0]
    author_names.append(name_reversed)
    
print(len(author_names))

# %%
# inspect 
author_names[:5]

# %% [markdown]
# #### Standardise spacing

# %%
# --- Standardise spacing before and after names ---
#first, strip any spaces that may be there (before, and then after)
names_standardised_space = []

for name in author_names:
    name_cleaned = name.lstrip()
    name_cleaned = name_cleaned.rstrip()
    names_standardised_space.append(name_cleaned)

print(len(names_standardised_space))

# %% [markdown]
# #### Remove initals

# %%
# --- Remove initials --- 
names_remove_initials = []

for name in names_standardised_space:
    #check if the name has an initial 
    if '.' in name:
        #if it does, find the index of the dot 
        stop = name.find('.')
        #take one index less of this to include initial letter
        start = stop - 1
        #remove these from the name 
        initials_removed = name[0: start:] + name[stop + 1::]
        names_remove_initials.append(initials_removed)
    else:
        names_remove_initials.append(name)

print(names_remove_initials[:5])
print(f"There are {len(names_remove_initials)} authors.")

# %%
# --- remove second layer of initials --- 
names_remove_initials2 = []

for name in names_remove_initials:
    #check if the name has another initial 
    if '.' in name:
        #if it does, find the index of the dot 
        stop = name.find('.')
        #take one index less of this to include initial letter
        start = stop - 1
        #remove these from the name 
        initials_removed = name[0: start:] + name[stop + 1::]
        names_remove_initials2.append(initials_removed)
    else:
        names_remove_initials2.append(name)

print(f"There are {len(names_remove_initials2)} authors.")

# %%
# --- remove third layer of initials --- 
names_remove_initials3 = []

for name in names_remove_initials2:
    #check if the name has another initial 
    if '.' in name:
        #if it does, find the index of the dot 
        stop = name.find('.')
        #take one index less of this to include initial letter
        start = stop - 1
        #remove these from the name 
        initials_removed = name[0: start:] + name[stop + 1::]
        names_remove_initials3.append(initials_removed)
    else:
        names_remove_initials3.append(name)

print(f"There are {len(names_remove_initials3)} authors.")

# %% [markdown]
# #### Standardise spacing between names

# %%
# --- Fix spacing between names --- 
names_one_space_between = []

for name in names_remove_initials3:
    #split the string and join them together with a single space
    standard_space = ' '.join(name.split())
    names_one_space_between.append(standard_space)

names_one_space_between[:5]

# %% [markdown]
# #### Centre names with space before and after

# %%
# --- Add space before and after name to enable easier searching for them ---
names_of_authors = []

for name in names_one_space_between:
    name_len = len(name) + 2
    name_centered = name.center(name_len)
    names_of_authors.append(name_centered)

names_of_authors[:5]

# %% [markdown]
# #### Finally, remove duplicates

# %%
# --- Remove duplicates by converting to a dictionary, and then back to a list --- 
print(f"There were originally {len(names_of_authors)} names in the author list.")

names_of_authors_no_dups = list(dict.fromkeys(names_of_authors))
print(f"With duplicates removed, there are now {len(names_of_authors_no_dups)} names in the author list.")

# %%
# --- inspect author list ---
author_names = names_of_authors_no_dups

author_names

# %% [markdown]
# #### Save the list of author names

# %%
output_file = open('../data/preprocessed_data/author_names.txt', 'w')

for name in author_names:
    output_file.write(name + '\n')

output_file.close()

# %% [markdown]
# ## Extracting the Dates to Search

# %% [markdown]
# Here, we want to search for the news articles which may be related to each of these research papers. Thus, we'll set up some criteria [better description]

# %%
# --- Make a new dataframe for working with dates ---
date_df = metadata

# --- Make date colume into date_time format ---
date_df['Date'] = pd.to_datetime(date_df['Date'], format="%Y-%m-%d")
date_df[:3]
# Out:
#                                              Authors  \
# 1  Griffiths, RR; Johnson, MW; Carducci, MA; Umbr...
# 2  Grob, CS; Danforth, AL; Chopra, GS; Hagerty, M...
# 3                                        Nichols, DE
#
#                                    Author.Full.Names  \
# 1  Griffiths, Roland R.; Johnson, Matthew W.; Car...
# 2  Grob, Charles S.; Danforth, Alicia L.; Chopra,...
# 3                                  Nichols, David E.
#
#                                        Article.Title  \
# 1  Psilocybin produces substantial and sustained ...
# 2  Pilot Study of Psilocybin Treatment for Anxiet...
# 3                                       Psychedelics
#
#                      Source.Title Language Document.Type  \
# 1   JOURNAL OF PSYCHOPHARMACOLOGY  English       Article
# 2  ARCHIVES OF GENERAL PSYCHIATRY  English       Article
# 3         PHARMACOLOGICAL REVIEWS  English        Review
#
#                                      Author.Keywords  \
# 1  Psilocybin; hallucinogen; cancer; anxiety; dep...
# 2                                                NaN
# 3                                                NaN
#
#                                        Keywords.Plus  \
# 1  QUALITY-OF-LIFE; MYSTICAL EXPERIENCE QUESTIONN...
# 2                                      PSYCHOTHERAPY
# 3  LYSERGIC-ACID DIETHYLAMIDE; SEROTONIN 5-HT2A R...
#
#                                             Abstract     Email.Addresses  ...  \
# 1  Cancer patients often develop chronic, clinica...     rgriff@jhmi.edu  ...
# 2  Context: Researchers conducted extensive inves...  cgrob@labiomed.org  ...
# 3  Psychedelics (serotonergic hallucinogens) are ...   drdave@purdue.edu  ...
#
#    Publication.Date  Publication.Year                                 DOI  \
# 1                12              2016            10.1177/0269881116675513
# 2                 1              2011  10.1001/archgenpsychiatry.2010.116
# 3                 4              2016               10.1124/pr.115.011478
#
#    Book.DOI   Pubmed.Id Open.Access.Designations  Highly.Cited.Status  \
# 1       NaN  27909165.0  hybrid, Green Published                    Y
# 2       NaN  20819978.0                   Bronze                    Y
# 3       NaN  26841800.0  Bronze, Green Published                    Y
#
#    Hot.Paper.Status Publication.Month       Date
# 1                 N               Dec 2016-12-01
# 2                 N               Jan 2011-01-01
# 3                 N               Apr 2016-04-01
#
# [3 rows x 26 columns]

# %%
# --- Make a column with dates shifted 3 months --- 
date_df['DateShift'] = pd.DatetimeIndex(date_df['Date'] ) + pd.DateOffset(months = 3)

# %%
date_df[:3]
# Out:
#                                              Authors  \
# 1  Griffiths, RR; Johnson, MW; Carducci, MA; Umbr...
# 2  Grob, CS; Danforth, AL; Chopra, GS; Hagerty, M...
# 3                                        Nichols, DE
#
#                                    Author.Full.Names  \
# 1  Griffiths, Roland R.; Johnson, Matthew W.; Car...
# 2  Grob, Charles S.; Danforth, Alicia L.; Chopra,...
# 3                                  Nichols, David E.
#
#                                        Article.Title  \
# 1  Psilocybin produces substantial and sustained ...
# 2  Pilot Study of Psilocybin Treatment for Anxiet...
# 3                                       Psychedelics
#
#                      Source.Title Language Document.Type  \
# 1   JOURNAL OF PSYCHOPHARMACOLOGY  English       Article
# 2  ARCHIVES OF GENERAL PSYCHIATRY  English       Article
# 3         PHARMACOLOGICAL REVIEWS  English        Review
#
#                                      Author.Keywords  \
# 1  Psilocybin; hallucinogen; cancer; anxiety; dep...
# 2                                                NaN
# 3                                                NaN
#
#                                        Keywords.Plus  \
# 1  QUALITY-OF-LIFE; MYSTICAL EXPERIENCE QUESTIONN...
# 2                                      PSYCHOTHERAPY
# 3  LYSERGIC-ACID DIETHYLAMIDE; SEROTONIN 5-HT2A R...
#
#                                             Abstract     Email.Addresses  ...  \
# 1  Cancer patients often develop chronic, clinica...     rgriff@jhmi.edu  ...
# 2  Context: Researchers conducted extensive inves...  cgrob@labiomed.org  ...
# 3  Psychedelics (serotonergic hallucinogens) are ...   drdave@purdue.edu  ...
#
#    Publication.Year                                 DOI  Book.DOI   Pubmed.Id  \
# 1              2016            10.1177/0269881116675513       NaN  27909165.0
# 2              2011  10.1001/archgenpsychiatry.2010.116       NaN  20819978.0
# 3              2016               10.1124/pr.115.011478       NaN  26841800.0
#
#   Open.Access.Designations Highly.Cited.Status  Hot.Paper.Status  \
# 1  hybrid, Green Published                   Y                 N
# 2                   Bronze                   Y                 N
# 3  Bronze, Green Published                   Y                 N
#
#    Publication.Month       Date  DateShift
# 1                Dec 2016-12-01 2017-03-01
# 2                Jan 2011-01-01 2011-04-01
# 3                Apr 2016-04-01 2016-07-01
#
# [3 rows x 27 columns]

# %%
dates_to_unzip = date_df[['Date', 'DateShift']]
dates_to_unzip
# Out:
#          Date  DateShift
# 1  2016-12-01 2017-03-01
# 2  2011-01-01 2011-04-01
# 3  2016-04-01 2016-07-01
# 4  2016-07-01 2016-10-01
# 5  2012-02-01 2012-05-01
# ..        ...        ...
# 80 2021-02-01 2021-05-01
# 81 2020-01-01 2020-04-01
# 82 2020-11-01 2021-02-01
# 83 2020-04-01 2020-07-01
# 84 2020-03-01 2020-06-01
#
# [84 rows x 2 columns]

# %%
test = dates_to_unzip

# %%
test = sorted(test['Date'])

# %%
test
# Out:
# [Timestamp('2011-01-01 00:00:00'),
#  Timestamp('2012-02-01 00:00:00'),
#  Timestamp('2012-12-01 00:00:00'),
#  Timestamp('2013-12-01 00:00:00'),
#  Timestamp('2014-02-01 00:00:00'),
#  Timestamp('2015-02-01 00:00:00'),
#  Timestamp('2015-03-01 00:00:00'),
#  Timestamp('2015-08-01 00:00:00'),
#  Timestamp('2015-10-01 00:00:00'),
#  Timestamp('2016-02-01 00:00:00'),
#  Timestamp('2016-02-01 00:00:00'),
#  Timestamp('2016-03-01 00:00:00'),
#  Timestamp('2016-04-01 00:00:00'),
#  Timestamp('2016-04-01 00:00:00'),
#  Timestamp('2016-06-01 00:00:00'),
#  Timestamp('2016-07-01 00:00:00'),
#  Timestamp('2016-09-01 00:00:00'),
#  Timestamp('2016-09-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-02-01 00:00:00'),
#  Timestamp('2017-04-01 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-08-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-10-01 00:00:00'),
#  Timestamp('2017-10-01 00:00:00'),
#  Timestamp('2017-11-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-05-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-07-01 00:00:00'),
#  Timestamp('2019-09-01 00:00:00'),
#  Timestamp('2019-11-01 00:00:00'),
#  Timestamp('2019-11-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-02-01 00:00:00'),
#  Timestamp('2020-02-01 00:00:00'),
#  Timestamp('2020-02-01 00:00:00'),
#  Timestamp('2020-03-01 00:00:00'),
#  Timestamp('2020-04-01 00:00:00'),
#  Timestamp('2020-04-01 00:00:00'),
#  Timestamp('2020-04-01 00:00:00'),
#  Timestamp('2020-09-01 00:00:00'),
#  Timestamp('2020-11-01 00:00:00'),
#  Timestamp('2020-11-01 00:00:00'),
#  Timestamp('2021-02-01 00:00:00'),
#  Timestamp('2021-04-01 00:00:00'),
#  Timestamp('2021-04-01 00:00:00'),
#  Timestamp('2021-04-01 00:00:00'),
#  Timestamp('2021-05-01 00:00:00')]

# %%
# remove duplicates 
test = list(dict.fromkeys(test))
print(len(test))
# Out:
# 48

# %%
test = sorted(test)
test
# Out:
# [Timestamp('2011-01-01 00:00:00'),
#  Timestamp('2012-02-01 00:00:00'),
#  Timestamp('2012-12-01 00:00:00'),
#  Timestamp('2013-12-01 00:00:00'),
#  Timestamp('2014-02-01 00:00:00'),
#  Timestamp('2015-02-01 00:00:00'),
#  Timestamp('2015-03-01 00:00:00'),
#  Timestamp('2015-08-01 00:00:00'),
#  Timestamp('2015-10-01 00:00:00'),
#  Timestamp('2016-02-01 00:00:00'),
#  Timestamp('2016-03-01 00:00:00'),
#  Timestamp('2016-04-01 00:00:00'),
#  Timestamp('2016-06-01 00:00:00'),
#  Timestamp('2016-07-01 00:00:00'),
#  Timestamp('2016-09-01 00:00:00'),
#  Timestamp('2016-12-01 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-02-01 00:00:00'),
#  Timestamp('2017-04-01 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-08-01 00:00:00'),
#  Timestamp('2017-09-01 00:00:00'),
#  Timestamp('2017-10-01 00:00:00'),
#  Timestamp('2017-11-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2018-02-01 00:00:00'),
#  Timestamp('2018-03-01 00:00:00'),
#  Timestamp('2018-06-01 00:00:00'),
#  Timestamp('2018-07-01 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-10-01 00:00:00'),
#  Timestamp('2018-11-01 00:00:00'),
#  Timestamp('2019-02-01 00:00:00'),
#  Timestamp('2019-03-01 00:00:00'),
#  Timestamp('2019-05-01 00:00:00'),
#  Timestamp('2019-06-01 00:00:00'),
#  Timestamp('2019-07-01 00:00:00'),
#  Timestamp('2019-09-01 00:00:00'),
#  Timestamp('2019-11-01 00:00:00'),
#  Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-02-01 00:00:00'),
#  Timestamp('2020-03-01 00:00:00'),
#  Timestamp('2020-04-01 00:00:00'),
#  Timestamp('2020-09-01 00:00:00'),
#  Timestamp('2020-11-01 00:00:00'),
#  Timestamp('2021-02-01 00:00:00'),
#  Timestamp('2021-04-01 00:00:00'),
#  Timestamp('2021-05-01 00:00:00')]
